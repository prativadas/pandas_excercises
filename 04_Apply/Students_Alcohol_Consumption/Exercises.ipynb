# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %% [markdown]
# apply() allow the users to pass a function and apply it on every single value of the Pandas series

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv', sep=(','))

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
# selects all rows and all columns beginning at 'school' up to and including 'guardian'

#Slice notation- start:stop:step

df.loc[:, 'school':'guardian']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
# only lambda() is created

capital = lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob'].apply(capital)
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393    Services
# 394       Other
# Name: Mjob, Length: 395, dtype: object

# %%
df['Fjob'].apply(capital)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393       Other
# 394     At_home
# Name: Fjob, Length: 395, dtype: object

# %%
# using lamda() in one line. as it works on series only 

#Series is a 1D labeled array capable of holding data of any type

df['Mjob'].apply(lambda x: x.capitalize())
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393    Services
# 394       Other
# Name: Mjob, Length: 395, dtype: object

# %%
df['Mjob'].apply( lambda x: x.upper())
# Out:
# 0       AT_HOME
# 1       AT_HOME
# 2       AT_HOME
# 3        HEALTH
# 4         OTHER
#          ...
# 390    SERVICES
# 391    SERVICES
# 392       OTHER
# 393    SERVICES
# 394       OTHER
# Name: Mjob, Length: 395, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  ...  \
# 394     MS   M   19       U     LE3       T     1     1  other  at_home  ...
#
#     famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 394      3        2      3     3     3      5        5  8  9  9
#
# [1 rows x 33 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# we apply the lamda() to original df.

df['Mjob'] = df['Mjob'].apply(lambda x: x.capitalize())

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     other
# 2       GP   F   15       U     LE3       T     1     1   At_home     other
# 3       GP   F   15       U     GT3       T     4     2    Health  services
# 4       GP   F   16       U     GT3       T     3     3     Other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  services
# 391     MS   M   17       U     LE3       T     3     1  Services  services
# 392     MS   M   21       R     GT3       T     1     1     Other     other
# 393     MS   M   18       R     LE3       T     3     2  Services     other
# 394     MS   M   19       U     LE3       T     1     1     Other   at_home
#
# ...

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(x):
    if x > 17:
        return True
    else:
        return False

# %%
# majority() applied to age column

df['legal_drinker'] = df['age'].apply(majority)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     other
# 2       GP   F   15       U     LE3       T     1     1   At_home     other
# 3       GP   F   15       U     GT3       T     4     2    Health  services
# 4       GP   F   16       U     GT3       T     3     3     Other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  services
# 391     MS   M   17       U     LE3       T     3     1  Services  services
# 392     MS   M   21       R     GT3       T     1     1     Other     other
# 393     MS   M   18       R     LE3       T     3     2  Services     other
# 394     MS   M   19       U     LE3       T     1     1     Other   at_home
#
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df.select_dtypes('number')
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# ...

# %%
# all numeric numbers are selected from df

df.select_dtypes('number')*10
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    180    40    40          20         20         0      40        30
# 1    170    10    10          10         20         0      50        30
# 2    150    10    10          10         20        30      40        30
# 3    150    40    20          10         30         0      30        20
# 4    160    30    30          10         20         0      40        30
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390  200    20    20          10         20        20      50        50
# 391  170    30    10          20         10         0      20        40
# 392  210    10    10          10         10        30      50        50
# 393  180    30    20          30         10         0      40        40
# 394  190    10    10          10         10         0      30        20
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3
# ...
