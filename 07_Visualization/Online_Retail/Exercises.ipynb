# %% [markdown]
# # Online Retails Purchase

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib

# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import seaborn as sns

# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seaborn graphs to a better style
sns.set(style="ticks")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called online_rt
# Note: if you receive a utf-8 decode error, set `encoding = 'latin1'` in `pd.read_csv()`.

# %%
online_rt = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv', encoding = 'latin1')

# %%
online_rt.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
online_rt.shape
# Out:
# (541909, 8)

# %% [markdown]
# ### Step 4. Create a histogram with the 10 countries that have the most 'Quantity' ordered except UK

# %%
df1 = online_rt.groupby('Country').sum()
df1
# Out:
#                       Quantity     UnitPrice    CustomerID
# Country
# Australia                83653  4.054750e+03  1.569300e+07
# Austria                   4827  1.701520e+03  5.021102e+06
# Bahrain                    260  8.657000e+01  2.100270e+05
# Belgium                  23152  7.540130e+03  2.571829e+07
# Brazil                     356  1.426000e+02  4.086080e+05
# Canada                    2763  9.105800e+02  2.615483e+06
# Channel Islands           9479  3.738550e+03  1.128522e+07
# Cyprus                    6317  3.920070e+03  7.715880e+06
# Czech Republic             592  8.815000e+01  3.834300e+05
# Denmark                   8188  1.266950e+03  4.876734e+06
# EIRE                    142637  4.844719e+04  1.103917e+08
# European Community         497  2.940500e+02  9.215880e+05
# Finland                  10666  3.786850e+03  8.699324e+06
# France                  110480  4.303199e+04  1.076489e+08
# Germany                 117448  3.766600e+04  1.200751e+08
# ...

# %%
#head =11 as we have to delete UK

df1 = df1.sort_values('Quantity', ascending=False).head(11)

df1
# Out:
#                 Quantity     UnitPrice    CustomerID
# Country
# United Kingdom   4263829  2.245715e+06  5.626433e+09
# Netherlands       200128  6.492550e+03  3.419054e+07
# EIRE              142637  4.844719e+04  1.103917e+08
# Germany           117448  3.766600e+04  1.200751e+08
# France            110480  4.303199e+04  1.076489e+08
# Australia          83653  4.054750e+03  1.569300e+07
# Sweden             35637  1.806830e+03  6.790083e+06
# Switzerland        30325  6.813690e+03  2.377592e+07
# Spain              26824  1.263345e+04  3.268929e+07
# Japan              25218  8.148600e+02  4.567292e+06
# Belgium            23152  7.540130e+03  2.571829e+07

# %%
# we remove UK as per question, in df1 indexing is based on country

df1 = df1.drop(['United Kingdom'])

df1
# Out:
#              Quantity  UnitPrice   CustomerID
# Country
# Netherlands    200128    6492.55   34190538.0
# EIRE           142637   48447.19  110391745.0
# Germany        117448   37666.00  120075093.0
# France         110480   43031.99  107648864.0
# Australia       83653    4054.75   15693002.0
# Sweden          35637    1806.83    6790083.0
# Switzerland     30325    6813.69   23775916.0
# Spain           26824   12633.45   32689291.0
# Japan           25218     814.86    4567292.0
# Belgium         23152    7540.13   25718288.0

# %%
# create the plot
df1['Quantity'].plot(kind='bar' ,color=['C0', 'C1', 'C2', 'C3', 'C4','C5', 'C6', 'C7', 'C8', 'C9'])

# Set the title and labels
plt.xlabel('Countries')
plt.ylabel('Quantity')
plt.title('10 Countries with most orders')

# show the plot
plt.show()

# %% [markdown]
# ### Step 5.  Exclude negative Quantity entries

# %%
online_rt.Quantity
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 541909, dtype: int64

# %%
# only positive quantity value

online_rt[online_rt['Quantity'] > 0]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#only negative quantity value

online_rt[online_rt['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### Step 6. Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries (except UK)

# %%
# we first groupby based on CustomerID, Country

df2 = online_rt.groupby(['CustomerID', 'Country']).sum()
df2
# Out:
#                            Quantity  UnitPrice
# CustomerID Country
# 12346.0    United Kingdom         0       2.08
# 12347.0    Iceland             2458     481.21
# 12348.0    Finland             2341     178.71
# 12349.0    Italy                631     605.10
# 12350.0    Norway               197      65.30
# ...                             ...        ...
# 18280.0    United Kingdom        45      47.65
# 18281.0    United Kingdom        54      39.36
# 18282.0    United Kingdom        98      62.68
# 18283.0    United Kingdom      1397    1220.93
# 18287.0    United Kingdom      1586     104.55
#
# [4380 rows x 2 columns]

# %%
df2 = df2.sort_values('Quantity', ascending=False).head(3)
df2
# Out:
#                         Quantity  UnitPrice
# CustomerID Country
# 14646.0    Netherlands    196719    5400.21
# 12415.0    Australia       77242    2499.82
# 14911.0    EIRE            77180   31060.66

# %%
df2.index
# Out:
# MultiIndex([(14646.0, 'Netherlands'),
#             (12415.0,   'Australia'),
#             (14911.0,        'EIRE')],
#            names=['CustomerID', 'Country'])

# %%
# get the value of the index and put in the column Country

df2['Country'] = df2.index.get_level_values(1)

df2
# Out:
#                         Quantity  UnitPrice      Country
# CustomerID Country
# 14646.0    Netherlands    196719    5400.21  Netherlands
# 12415.0    Australia       77242    2499.82    Australia
# 14911.0    EIRE            77180   31060.66         EIRE

# %%
df2.index
# Out:
# MultiIndex([(14646.0, 'Netherlands'),
#             (12415.0,   'Australia'),
#             (14911.0,        'EIRE')],
#            names=['CustomerID', 'Country'])

# %%
df2.Country.value_counts()
# Out:
# EIRE           1
# Australia      1
# Netherlands    1
# Name: Country, dtype: int64

# %%
# creates the FaceGrid
g = sns.FacetGrid(df2, col='Country')

# map over a make a scatterplot
g.map(plt.scatter, "Quantity", "UnitPrice", alpha=1)

# adds legend
g.add_legend()

# %%
####### another way to approach

# %%
# what's wrong in above method find out and  solve. didnt understand solution also

#top_countries are'Netherlands', 'EIRE', 'Germany'

#lets extract only the top 3 country info INDIVIDUALLY

online_rt[online_rt.Country == 'Netherlands'].head()
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 385      536403     22867            HAND WARMER BIRD DESIGN        96
# 386      536403      POST                            POSTAGE         1
# 37952    539491     21981       PACK OF 12 WOODLAND TISSUES         12
# 37953    539491     21986   PACK OF 12 PINK POLKADOT TISSUES        12
# 37954    539491     22720  SET OF 3 CAKE TINS PANTRY DESIGN          2
#
#           InvoiceDate  UnitPrice  CustomerID      Country
# 385     12/1/10 11:27       1.85     12791.0  Netherlands
# 386     12/1/10 11:27      15.00     12791.0  Netherlands
# 37952  12/20/10 10:09       0.29     14646.0  Netherlands
# 37953  12/20/10 10:09       0.29     14646.0  Netherlands
# 37954  12/20/10 10:09       4.95     14646.0  Netherlands

# %%
online_rt[online_rt.Country == 'EIRE'].head()
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1404    536540     22968           ROSE COTTAGE KEEPSAKE BOX          4
# 1405    536540    85071A  BLUE CHARLIE+LOLA PERSONAL DOORSIGN         6
# 1406    536540    85071C    CHARLIE+LOLA"EXTREMELY BUSY" SIGN         6
# 1407    536540     22355            CHARLOTTE BAG SUKI DESIGN        50
# 1408    536540     21579      LOLITA  DESIGN  COTTON TOTE BAG         6
#
#         InvoiceDate  UnitPrice  CustomerID Country
# 1404  12/1/10 14:05       9.95     14911.0    EIRE
# 1405  12/1/10 14:05       2.95     14911.0    EIRE
# 1406  12/1/10 14:05       2.55     14911.0    EIRE
# 1407  12/1/10 14:05       0.85     14911.0    EIRE
# 1408  12/1/10 14:05       2.25     14911.0    EIRE

# %%
online_rt[online_rt.Country == 'Germany'].head()
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1109    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#         InvoiceDate  UnitPrice  CustomerID  Country
# 1109  12/1/10 13:04       2.95     12662.0  Germany
# 1110  12/1/10 13:04       2.55     12662.0  Germany
# 1111  12/1/10 13:04       0.85     12662.0  Germany
# 1112  12/1/10 13:04       1.65     12662.0  Germany
# 1113  12/1/10 13:04       1.95     12662.0  Germany

# %%
# first we group df by CustomerID, Country. 
#if we do this then we cant pass Country as col name in isin() in next step.
#so we do groupby after

# df_top = online_rt.groupby(['CustomerID', 'Country']).sum()

# df_top

# %%
#top_countries are'Netherlands', 'EIRE', 'Germany' and their info is in single df

df_top = online_rt[online_rt['Country'].isin([ 'Netherlands', 'EIRE', 'Germany'])]

df_top
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 385       536403     22867              HAND WARMER BIRD DESIGN        96
# 386       536403      POST                              POSTAGE         1
# 1109      536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110      536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111      536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# ...          ...       ...                                  ...       ...
# 541801    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 541802    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 541803    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 541804    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 541805    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#           InvoiceDate  UnitPrice  CustomerID      Country
# ...

# %%
# removed negative quantity values

df_top = df_top[df_top['Quantity'] > 0]

df_top.head()
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 385     536403     22867              HAND WARMER BIRD DESIGN        96
# 386     536403      POST                              POSTAGE         1
# 1109    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
#
#         InvoiceDate  UnitPrice  CustomerID      Country
# 385   12/1/10 11:27       1.85     12791.0  Netherlands
# 386   12/1/10 11:27      15.00     12791.0  Netherlands
# 1109  12/1/10 13:04       2.95     12662.0      Germany
# 1110  12/1/10 13:04       2.55     12662.0      Germany
# 1111  12/1/10 13:04       0.85     12662.0      Germany

# %%
# if we make country as index here then how we will use country as col in scatterplot

# so we create a new col in df_top same name as Country

##It sums all the (non-indexical) columns that have numerical values under each group

df_top = df_top.groupby(['CustomerID', 'Country']).sum()

df_top
# Out:
#                         Quantity  UnitPrice
# CustomerID Country
# 12426.0    Germany           258     118.09
# 12427.0    Germany           533     142.26
# 12468.0    Germany           366     133.57
# 12471.0    Germany          8212    1978.17
# 12472.0    Germany          4148     812.81
# ...                          ...        ...
# 14016.0    EIRE             2125     635.88
# 14156.0    EIRE            57885    5357.68
# 14335.0    Germany           379     144.24
# 14646.0    Netherlands    197491    5176.09
# 14911.0    EIRE            80515   26185.72
#
# [106 rows x 2 columns]

# %%
# get the value of the index and put in the column Country

df_top['Country'] = df_top.index.get_level_values(1)

df_top
# Out:
#                         Quantity  UnitPrice      Country
# CustomerID Country
# 12426.0    Germany           258     118.09      Germany
# 12427.0    Germany           533     142.26      Germany
# 12468.0    Germany           366     133.57      Germany
# 12471.0    Germany          8212    1978.17      Germany
# 12472.0    Germany          4148     812.81      Germany
# ...                          ...        ...          ...
# 14016.0    EIRE             2125     635.88         EIRE
# 14156.0    EIRE            57885    5357.68         EIRE
# 14335.0    Germany           379     144.24      Germany
# 14646.0    Netherlands    197491    5176.09  Netherlands
# 14911.0    EIRE            80515   26185.72         EIRE
#
# [106 rows x 3 columns]

# %%
# each plot contains 94, 9, 3 data points respectively

# we're going to be plotting one dot per CustomerID's on our plot

df_top.Country.value_counts()
# Out:
# Germany        94
# Netherlands     9
# EIRE            3
# Name: Country, dtype: int64

# %% [markdown]
# FacetGrid class helps in visualizing distribution of one variable as well as
# the relationship between multiple variables separately within subsets of your dataset using multiple panels.

# %%
# we remove negative qunatity values so that values come after 0 in graph

#Proportional opacity of the points.stacks the higher-alpha points atop the lower ones.

# creates the FaceGrid
g = sns.FacetGrid(df_top, col='Country')

# map over a make a scatterplot
g.map(plt.scatter, "Quantity", "UnitPrice", alpha=1, color ='orange', s =100)

# adds legend
g.add_legend()

# %% [markdown]
# ### Step 7. Investigate why the previous results look so uninformative.
#
# This section might seem a bit tedious to go through. But I've thought of it as some kind of a simulation of problems one might encounter when dealing with data and other people. Besides there is a prize at the end (i.e. Section 8).
#
# (But feel free to jump right ahead into Section 8 if you want; it doesn't require that you finish this section.)
#
# #### Step 7.1 Look at the first line of code in Step 6. And try to figure out if it leads to any kind of problem.
# ##### Step 7.1.1 Display the first few rows of that DataFrame.

# %%
df_top.head()
# Out:
#                     Quantity  UnitPrice  Country
# CustomerID Country
# 12426.0    Germany       258     118.09  Germany
# 12427.0    Germany       533     142.26  Germany
# 12468.0    Germany       366     133.57  Germany
# 12471.0    Germany      8212    1978.17  Germany
# 12472.0    Germany      4148     812.81  Germany

# %% [markdown]
# ##### Step 7.1.2 Think about what that piece of code does and display the dtype of `UnitPrice`

# %%
online_rt.UnitPrice.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ##### Step 7.1.3 Pull data from `online_rt`for `CustomerID`s 12346.0 and 12347.0.

# %%
online_rt.CustomerID.dtype
# Out:
# dtype('float64')

# %%
online_rt[online_rt['CustomerID'].isin([12346.0, 12347.0])]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 14938     537626     85116      BLACK CANDELABRA T-LIGHT HOLDER        12
# 14939     537626     22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 14940     537626     71477    COLOUR GLASS. STAR T-LIGHT HOLDER        12
# 14941     537626     22492              MINI PAINT SET VINTAGE         36
# 14942     537626     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        12
# ...          ...       ...                                  ...       ...
# 535010    581180     20719               WOODLAND CHARLOTTE BAG        10
# 535011    581180     21265         PINK GOOSE FEATHER TREE 60CM        12
# 535012    581180     23271  CHRISTMAS TABLE SILVER CANDLE SPIKE        16
# 535013    581180     23506         MINI PLAYING CARDS SPACEBOY         20
# 535014    581180     23508       MINI PLAYING CARDS DOLLY GIRL         20
#
#           InvoiceDate  UnitPrice  CustomerID  Country
# ...

# %%
online_rt[online_rt.CustomerID == 12347.0]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 14938     537626     85116      BLACK CANDELABRA T-LIGHT HOLDER        12
# 14939     537626     22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 14940     537626     71477    COLOUR GLASS. STAR T-LIGHT HOLDER        12
# 14941     537626     22492              MINI PAINT SET VINTAGE         36
# 14942     537626     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        12
# ...          ...       ...                                  ...       ...
# 535010    581180     20719               WOODLAND CHARLOTTE BAG        10
# 535011    581180     21265         PINK GOOSE FEATHER TREE 60CM        12
# 535012    581180     23271  CHRISTMAS TABLE SILVER CANDLE SPIKE        16
# 535013    581180     23506         MINI PLAYING CARDS SPACEBOY         20
# 535014    581180     23508       MINI PLAYING CARDS DOLLY GIRL         20
#
#           InvoiceDate  UnitPrice  CustomerID  Country
# ...

# %%
online_rt[online_rt.CustomerID == 12346.0]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 61619  1/18/11 10:01       1.04     12346.0  United Kingdom
# 61624  1/18/11 10:17       1.04     12346.0  United Kingdom

# %% [markdown]
# #### Step 7.2 Reinterpreting the initial problem.
#
# To reiterate the question that we were dealing with:
# "Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries"
#
# The question is open to a set of different interpretations.
# We need to disambiguate.
#
# We could do a single plot by looking at all the data from the top 3 countries.
# Or we could do one plot per country. To keep things consistent with the rest of the exercise,
# let's stick to the latter oprion. So that's settled.
#
# But "top 3 countries" with respect to what? Two answers suggest themselves:
# Total sales volume (i.e. total quantity sold) or total sales (i.e. revenue).
# This exercise goes for sales volume, so let's stick to that.
#
# ##### Step 7.2.1 Find out the top 3 countries in terms of sales volume.

# %%
sales_top = online_rt.groupby('Country').sum()

sales_top
# Out:
#                       Quantity     UnitPrice    CustomerID
# Country
# Australia                83653  4.054750e+03  1.569300e+07
# Austria                   4827  1.701520e+03  5.021102e+06
# Bahrain                    260  8.657000e+01  2.100270e+05
# Belgium                  23152  7.540130e+03  2.571829e+07
# Brazil                     356  1.426000e+02  4.086080e+05
# Canada                    2763  9.105800e+02  2.615483e+06
# Channel Islands           9479  3.738550e+03  1.128522e+07
# Cyprus                    6317  3.920070e+03  7.715880e+06
# Czech Republic             592  8.815000e+01  3.834300e+05
# Denmark                   8188  1.266950e+03  4.876734e+06
# EIRE                    142637  4.844719e+04  1.103917e+08
# European Community         497  2.940500e+02  9.215880e+05
# Finland                  10666  3.786850e+03  8.699324e+06
# France                  110480  4.303199e+04  1.076489e+08
# Germany                 117448  3.766600e+04  1.200751e+08
# ...

# %%
sales_top = sales_top.Quantity.sort_values(ascending= False).head(4)

# %%
# if we remove uk

sales_top = sales_top.index[1:4]

sales_top
# Out:
# Index(['Netherlands', 'EIRE', 'Germany'], dtype='object', name='Country')

# %% [markdown]
# ##### Step 7.2.2
#
# Now that we have the top 3 countries, we can focus on the rest of the problem:
# "Quantity per UnitPrice by CustomerID".
# We need to unpack that.
#
# "by CustomerID" part is easy. That means we're going to be plotting one dot per CustomerID's on our plot. In other words, we're going to be grouping by CustomerID.
#
# "Quantity per UnitPrice" is trickier. Here's what we know:
# *One axis will represent a Quantity assigned to a given customer. This is easy; we can just plot the total  Quantity for each customer.
# *The other axis will represent a UnitPrice assigned to a given customer. Remember a single customer can have any number of orders with different prices, so summing up prices isn't quite helpful. Besides it's not quite clear what we mean when we say "unit price per customer"; it sounds like price of the customer! A reasonable alternative is that we assign each customer the average amount each has paid per item. So let's settle that question in that manner.
#
# #### Step 7.3 Modify, select and plot data
# ##### Step 7.3.1 Add a column to online_rt called `Revenue` calculate the revenue (Quantity * UnitPrice) from each sale.
# We will use this later to figure out an average price per customer.

# %%
online_rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
online_rt['Revenue'] = online_rt.Quantity * online_rt.UnitPrice

online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# ...

# %%
group = online_rt[online_rt.Country.isin(sales_top)].groupby(['CustomerID', 'Country'])

# %% [markdown]
# ##### Step 7.3.2 Group by `CustomerID` and `Country` and find out the average price (`AvgPrice`) each customer spends per unit.

# %%
# to find avg price we first find agg sum of quantity and revenue

group = group['Quantity','Revenue'].agg('sum')
# Out:
# <ipython-input-42-9fce3c6af4d9>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group = group['Quantity','Revenue'].agg('sum')

# %%
 group['avg price'] = group.Revenue/group.Quantity

# %%
group
# Out:
#                         Quantity    Revenue  avg price
# CustomerID Country
# 12426.0    Germany           258     582.73   2.258643
# 12427.0    Germany           236     708.37   3.001568
# 12468.0    Germany           364     724.04   1.989121
# 12471.0    Germany          7965   18740.92   2.352909
# 12472.0    Germany          4020    6229.48   1.549622
# ...                          ...        ...        ...
# 14016.0    EIRE             2124    4328.46   2.037881
# 14156.0    EIRE            57025  113384.14   1.988323
# 14335.0    Germany           379     468.26   1.235515
# 14646.0    Netherlands    196719  279489.02   1.420753
# 14911.0    EIRE            77180  132572.62   1.717707
#
# [107 rows x 3 columns]

# %%
# get the value of the index and put in the column Country

group['Country'] = group.index.get_level_values(1)

group
# Out:
#                         Quantity    Revenue  avg price      Country
# CustomerID Country
# 12426.0    Germany           258     582.73   2.258643      Germany
# 12427.0    Germany           236     708.37   3.001568      Germany
# 12468.0    Germany           364     724.04   1.989121      Germany
# 12471.0    Germany          7965   18740.92   2.352909      Germany
# 12472.0    Germany          4020    6229.48   1.549622      Germany
# ...                          ...        ...        ...          ...
# 14016.0    EIRE             2124    4328.46   2.037881         EIRE
# 14156.0    EIRE            57025  113384.14   1.988323         EIRE
# 14335.0    Germany           379     468.26   1.235515      Germany
# 14646.0    Netherlands    196719  279489.02   1.420753  Netherlands
# 14911.0    EIRE            77180  132572.62   1.717707         EIRE
#
# [107 rows x 4 columns]

# %% [markdown]
# ##### Step 7.3.3 Plot

# %%
# creates the FaceGrid
g = sns.FacetGrid(group, col="Country")

# map over a make a scatterplot
g.map(plt.scatter, "Quantity", "avg price", alpha=1 ,color ='Red', s =100 )

# adds legend
g.add_legend();

# %% [markdown]
# #### Step 7.4 What to do now?
# We aren't much better-off than what we started with. The data are still extremely scattered around and don't seem quite informative.
#
# But we shouldn't despair!
# There are two things to realize:
# 1) The data seem to be skewed towaards the axes (e.g. we don't have any values where Quantity = 50000 and AvgPrice = 5). So that might suggest a trend.
# 2) We have more data! We've only been looking at the data from 3 different countries and they are plotted on different graphs.
#
# So: we should plot the data regardless of `Country` and hopefully see a less scattered graph.
#
# ##### Step 7.4.1 Plot the data for each `CustomerID` on a single graph

# %%
new_group = online_rt.groupby('CustomerID')

new_group.head()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541768    581578      POST                              POSTAGE         3
# 541769    581578     21124   SET/10 BLUE POLKADOT PARTY CANDLES        24
# 541770    581578     21122   SET/10 PINK POLKADOT PARTY CANDLES        24
# 541771    581578     21121    SET/10 RED POLKADOT PARTY CANDLES        24
# 541772    581578     23389               SPACEBOY MINI BACKPACK         4
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# ...

# %%
new_group = new_group['Quantity','Revenue'].agg('sum')
# Out:
# <ipython-input-48-bb64d7030c0d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_group = new_group['Quantity','Revenue'].agg('sum')

# %%
 new_group['avg price'] = new_group.Revenue/new_group.Quantity

# %%
new_group
# Out:
#             Quantity  Revenue  avg price
# CustomerID
# 12346.0            0     0.00        NaN
# 12347.0         2458  4310.00   1.753458
# 12348.0         2341  1797.24   0.767723
# 12349.0          631  1757.55   2.785341
# 12350.0          197   334.40   1.697462
# ...              ...      ...        ...
# 18280.0           45   180.60   4.013333
# 18281.0           54    80.82   1.496667
# 18282.0           98   176.60   1.802041
# 18283.0         1397  2094.88   1.499556
# 18287.0         1586  1837.28   1.158436
#
# [4372 rows x 3 columns]

# %%
# map over a make a scatterplot
plt.scatter(new_group['Quantity'], new_group['avg price'], color = 'Purple', s=100)
plt.plot()
# Out:
# []

# %% [markdown]
# ##### Step 7.4.2 Zoom in so we can see that curve more clearly

# %%
plt.scatter(new_group['Quantity'], new_group['avg price'], color = 'Blue', s=50 )
plt.plot()


# plt.xlim(-50, 5000)
# plt.ylim(-2, 100)

plt.xlim(-150,5000) 
plt.ylim(-1,80)
# Out:
# (-1.0, 80.0)

# %% [markdown]
# ##### 8. Plot a line chart showing revenue (y) per UnitPrice (x).
#
# Did Step 7 give us any insights about the data? Sure! As average price increases, the quantity ordered decreses.  But that's hardly surprising. It would be surprising if that wasn't the case!
#
# Nevertheless the rate of drop in quantity is so drastic, it makes me wonder how our revenue changes with respect to item price. It would not be that surprising if it didn't change that much. But it would be interesting to know whether most of our revenue comes from expensive or inexpensive items, and how that relation looks like.
#
# That is what we are going to do now.
#
# #### 8.1 Group `UnitPrice` by intervals of 1 for prices [0,50), and sum `Quantity` and `Revenue`.

# %%
# this is one way to approach, but find what the issue here

# %%
new_unit = online_rt[online_rt['UnitPrice'].between(0,50)]

new_unit
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# ...

# %%
new_unit = new_unit.groupby(online_rt.UnitPrice).Revenue.sum()

# %% [markdown]
# #### 8.3 Plot.

# %%
new_unit.plot()
plt.xlabel('Unit Price')
plt.ylabel('Revenue')
plt.show()

# %%
# another way to solve the above question

# %%
bin_range = pd.interval_range(start=0, freq=1, end=49)

# %%
unit = online_rt.groupby(pd.cut(online_rt.UnitPrice, bins= bin_range)).Revenue.sum()

# %%
unit
# Out:
# UnitPrice
# (0, 1]      1.089068e+06
# (1, 2]      2.557511e+06
# (2, 3]      1.803382e+06
# (3, 4]      8.499193e+05
# (4, 5]      1.199347e+06
# (5, 6]      3.789279e+05
# (6, 7]      2.604464e+05
# (7, 8]      2.965417e+05
# (8, 9]      3.724522e+05
# (9, 10]     1.576296e+05
# (10, 11]    2.282689e+05
# (11, 12]    2.501608e+04
# (12, 13]    1.949849e+05
# (13, 14]    1.053364e+04
# (14, 15]    7.214595e+04
# (15, 16]    2.093207e+04
# (16, 17]    8.197150e+04
# (17, 18]    3.601663e+04
# (18, 19]    6.721600e+02
# (19, 20]    1.737452e+04
# (20, 21]    2.073507e+04
# (21, 22]    2.617530e+03
# (22, 23]   -2.253000e+01
# (23, 24]    2.600000e-01
# (24, 25]    4.190954e+04
# (25, 26]    1.198029e+04
# (26, 27]    5.487000e+01
# (27, 28]    8.794610e+03
# (28, 29]   -2.806000e+01
# (29, 30]    7.930630e+03
# (30, 31]   -9.110000e+01
# (31, 32]   -6.358000e+01
# (32, 33]    2.910190e+03
# (33, 34]    5.087000e+03
# (34, 35]    8.316130e+03
# (35, 36]    2.727860e+03
# ...

# %%
# lets do groupby 1st

# unit = online_rt.groupby(pd.cut(online_rt.UnitPrice, (0,10,20,30,40,50))).Revenue.sum()

# %%
unit.plot()
plt.xlabel('Unit Price')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# #### 8.4 Make it look nicer.
# x-axis needs values.
# y-axis isn't that easy to read; show in terms of millions.

# %%
#ticks() and yticks() function takes a list object as argument. 
# The elements in the list denote the positions on corresponding action 
# where ticks will be displayed.

unit.plot()
plt.xlabel('Unit Price')
plt.ylabel('Revenue')
           
plt.xticks(np.arange(0,50,3),np.arange(0,50,3))

plt.yticks([0, 500000, 1000000, 1500000, 2000000, 2500000],
           ['0', '$0.5M', '$1M', '$1.5M', '$2M', '$2.5M'])
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
