# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv', sep=',')

tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tips.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\prati\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tips.hist(bins = 5)
# Out:
# array([[<AxesSubplot:title={'center':'total_bill'}>,
#         <AxesSubplot:title={'center':'tip'}>],
#        [<AxesSubplot:title={'center':'size'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
tips.plot.hist(bins = 5, rwidth=0.9)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips.hist(bins = 5, column ='total_bill', grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'total_bill'}>]], dtype=object)

# %%
tips.hist(bins = 5, column ='total_bill', grid=False, figsize=(12,8), color='Orange', zorder=2, rwidth=0.9)
# Out:
# array([[<AxesSubplot:title={'center':'total_bill'}>]], dtype=object)

# %%
# plot histogram using seaborn

import seaborn as sns

# set seaborn style to white
sns.set_style("white")

# %% [markdown]
# ### displot() - visualizing the univariate or bivariate distribution of data ###

# %% [markdown]
# *kernel density estimate to smooth the histogram, providing complementary information about the shape of the distribution*

# %%
# bill = sns.histplot(tips, kde=True)

sns.displot(tips['total_bill'], kde=True)

plt.show()

# %%
#distplot() function combines the matplotlib hist function with the seaborn kdeplot()

sns.distplot(tips['total_bill'])

plt.show()
# Out:
# c:\users\prati\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips)

plt.show()

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %% [markdown]
# ## sns.pairplot() - To plot multiple pairwise bivariate distributions in a dataset, Plot pairwise relationships in a dataset.  ##

# %%
#understand how this scatter plot generated

#bivariate distributions plot

# sns.displot(data = tips, x='total_bill', y='tip')

# plt.show()

# %%
sns.pairplot(tips)

# %%
#hue - Variable in “data“ to map plot aspects to different colors.

sns.pairplot(tips, hue='sex')

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
# pairplot wont work here

# To draw a bivariate plot

# kind = 'kde' wont apply here as day is categorical 

sns.displot(data = tips, x = 'day', y='total_bill', color= 'Purple')

# sns.pairplot(data = tips, x = 'day', y='total_bill')

plt.show()

# %% [markdown]
# ## Categorical scatterplots- relplot, catplot(), stripplot()
#
# https://seaborn.pydata.org/tutorial/categorical.html
#
# https://www.geeksforgeeks.org/visualizing-relationship-between-variables-with-scatter-plots-in-seaborn/

# %%
sns.relplot(x ="day", y ="total_bill", data = tips, hue='day', style='day', size='size')

# %%
# Categorical scatterplots

#jitter parameter controls the magnitude of jitter

sns.catplot(x="day", y="total_bill", data=tips, jitter=True)

# %%
# kind='swarm' - prevents data points from overlapping

sns.catplot(x="day", y="total_bill", data=tips, kind='swarm')

# %% [markdown]
# ## As the size of the dataset grows, categorical scatter plots become limited in the information they can provide about the distribution of values within each category.

# %%
#  boxplot() shows the three quartile values of the distribution along with extreme values.

sns.catplot(x="day", y="total_bill", kind="box", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", inner="stick", split=True,
            palette="pastel", data=tips)

# %% [markdown]
# ## It can also be useful to combine swarmplot() or striplot() with a box plot or violin plot to show each observation along with a summary of the distribution:

# %%
g = sns.catplot(x="day", y="total_bill", kind="violin", inner=None, data=tips)
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips, ax=g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex
#
# https://seaborn.pydata.org/generated/seaborn.stripplot.html

# %%
sns.stripplot(data= tips, x = 'tip', y= 'day', hue='sex', size=8, jitter=0.10 )
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
sns.boxplot(x= 'day', y='total_bill', data=tips, hue='time', dodge=True, palette='pastel')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.
#
# https://seaborn.pydata.org/generated/seaborn.displot.html#seaborn.displot
#
# https://seaborn.pydata.org/generated/seaborn.FacetGrid.html

# %%
sns.stripplot(data=tips, x= 'time' , y = 'tip', order=['Dinner', 'Lunch'])
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.catplot(data=tips, x= 'time' , y = 'tip')

# %%
sns.displot(tips, x = 'tip', col= 'time')

# %%
g = sns.FacetGrid(tips,  col="time")

g.map_dataframe(sns.histplot, x="tip")

g.set_axis_labels("Total bill", "Tip")

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
g = sns.FacetGrid(tips,  col="sex", hue='smoker', )

g.map_dataframe(sns.scatterplot, x="total_bill", y="tip", alpha =0.7)

g.add_legend()

g.set_axis_labels("Total bill", "Tip")

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
